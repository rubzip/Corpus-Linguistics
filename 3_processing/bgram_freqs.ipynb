# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./bigram_frequencies.csv", index_col=0)
df.index = df.index.set_names(['bigram_text'])
df = df.reset_index()
df
# Out:
#                      bigram_text  hyperpartisan_freq  non_hyperpartisan_freq
# 0               ('the', 'first')               36498                   59794
# 1          ('first', 'official')                 135                     245
# 2        ('official', 'trailer')                  25                       2
# 3             ('trailer', 'for')                 216                      52
# 4         ('mockingjay', 'part')                  30                      14
# ...                          ...                 ...                     ...
# 2437335          ('paso', 'had')                   1                      18
# 2437336         ('tour', 'some')                   1                       4
# 2437337    ('tremendously', 'i')                   1                       3
# 2437338       ('damage', 'here')                   1                       5
# 2437339       ('david', 'noted')                   1                       2
#
# [2437340 rows x 3 columns]

# %%
import re

def str2tuple(x):
    match = re.match(r"\(\'(.+)\'.+\'(.+)\'", x)
    if match:
        return (match.group(1), match.group(2))

# %%
df['bigram'] = df['bigram_text'].map(convert)
df
# Out:
#                      bigram_text  hyperpartisan_freq  non_hyperpartisan_freq  \
# 0               ('the', 'first')               36498                   59794
# 1          ('first', 'official')                 135                     245
# 2        ('official', 'trailer')                  25                       2
# 3             ('trailer', 'for')                 216                      52
# 4         ('mockingjay', 'part')                  30                      14
# ...                          ...                 ...                     ...
# 2437335          ('paso', 'had')                   1                      18
# 2437336         ('tour', 'some')                   1                       4
# 2437337    ('tremendously', 'i')                   1                       3
# 2437338       ('damage', 'here')                   1                       5
# 2437339       ('david', 'noted')                   1                       2
#
#                       bigram
# 0               (the, first)
# 1          (first, official)
# 2        (official, trailer)
# 3             (trailer, for)
# 4         (mockingjay, part)
# ...                      ...
# 2437335          (paso, had)
# 2437336         (tour, some)
# 2437337    (tremendously, i)
# 2437338       (damage, here)
# 2437339       (david, noted)
#
# [2437340 rows x 4 columns]

# %%
articles = pd.read_csv("./content.csv")
N_hyperpartasian = articles["hyperpartasian"].sum()
N_non_hyperpartasian = len(articles) - N_hyperpartasian

# %%
with open("stopwords.txt", 'r') as f:
    stopwords = set(f.read().split())

contains_stopword = df["bigram"].map(lambda x: (x[0] in stopwords) or (x[1] in stopwords))
df = df[~contains_stopword]

df
# Out:
#                               bigram_text  hyperpartisan_freq  \
# 1                   ('first', 'official')                 135
# 22                     ('first', 'thing')                 584
# 40                       ('first', 'two')                 766
# 41                      ('two', 'movies')                  34
# 70                      ('destroy', 'us')                  87
# ...                                   ...                 ...
# 2003867                      ('de', 'le')                  38
# 2047220               ('girls', 'revolt')                  35
# 2092404               ('perez', 'molina')                  36
# 2120951  ('transportation', 'commission')                  44
# 2242636                ('ad', 'blocking')                  42
#
#          non_hyperpartisan_freq                        bigram  freq
# 1                           245             (first, official)   380
# 22                          679                (first, thing)  1263
# 40                         1237                  (first, two)  2003
# 41                           26                 (two, movies)    60
# 70                           46                 (destroy, us)   133
# ...                         ...                           ...   ...
# 2003867                     145                      (de, le)   183
# 2047220                      20               (girls, revolt)    55
# 2092404                      27               (perez, molina)    63
# 2120951                     126  (transportation, commission)   170
# 2242636                      30                (ad, blocking)    72
#
# [69972 rows x 5 columns]

# %%
df["freq"] = df["non_hyperpartisan_freq"] + df["hyperpartisan_freq"]
df
# Out:
#                               bigram_text  hyperpartisan_freq  \
# 1                   ('first', 'official')                 135
# 22                     ('first', 'thing')                 584
# 40                       ('first', 'two')                 766
# 41                      ('two', 'movies')                  34
# 70                      ('destroy', 'us')                  87
# ...                                   ...                 ...
# 2003867                      ('de', 'le')                  38
# 2047220               ('girls', 'revolt')                  35
# 2092404               ('perez', 'molina')                  36
# 2120951  ('transportation', 'commission')                  44
# 2242636                ('ad', 'blocking')                  42
#
#          non_hyperpartisan_freq                        bigram  freq
# 1                           245             (first, official)   380
# 22                          679                (first, thing)  1263
# 40                         1237                  (first, two)  2003
# 41                           26                 (two, movies)    60
# 70                           46                 (destroy, us)   133
# ...                         ...                           ...   ...
# 2003867                     145                      (de, le)   183
# 2047220                      20               (girls, revolt)    55
# 2092404                      27               (perez, molina)    63
# 2120951                     126  (transportation, commission)   170
# 2242636                      30                (ad, blocking)    72
#
# [69972 rows x 5 columns]

# %%
frequent = (df[["hyperpartisan_freq", "non_hyperpartisan_freq"]] >= 20).all(axis=1)
# frequent = (df["freq"] >= 20)
df = df[frequent]
df
# Out:
#                               bigram_text  hyperpartisan_freq  \
# 1                   ('first', 'official')                 135
# 22                     ('first', 'thing')                 584
# 40                       ('first', 'two')                 766
# 41                      ('two', 'movies')                  34
# 70                      ('destroy', 'us')                  87
# ...                                   ...                 ...
# 2003867                      ('de', 'le')                  38
# 2047220               ('girls', 'revolt')                  35
# 2092404               ('perez', 'molina')                  36
# 2120951  ('transportation', 'commission')                  44
# 2242636                ('ad', 'blocking')                  42
#
#          non_hyperpartisan_freq                        bigram  freq
# 1                           245             (first, official)   380
# 22                          679                (first, thing)  1263
# 40                         1237                  (first, two)  2003
# 41                           26                 (two, movies)    60
# 70                           46                 (destroy, us)   133
# ...                         ...                           ...   ...
# 2003867                     145                      (de, le)   183
# 2047220                      20               (girls, revolt)    55
# 2092404                      27               (perez, molina)    63
# 2120951                     126  (transportation, commission)   170
# 2242636                      30                (ad, blocking)    72
#
# [69972 rows x 5 columns]

# %%
df["p_hyperpartisan"] = df["hyperpartisan_freq"] / N_hyperpartasian
df["p_non_hyperpartisan"] = df["non_hyperpartisan_freq"] / N_non_hyperpartasian

df["o_hyperpartisan"] = df["p_hyperpartisan"] / (1 - df["p_hyperpartisan"])
df["o_non_hyperpartisan"] = df["p_non_hyperpartisan"] / (1 - df["p_non_hyperpartisan"])

df["r"] = np.log(df["o_hyperpartisan"] / df["o_non_hyperpartisan"])

df
# Out:
# C:\Users\ruben\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                               bigram_text  hyperpartisan_freq  \
# 1                   ('first', 'official')                 135
# 22                     ('first', 'thing')                 584
# 40                       ('first', 'two')                 766
# 41                      ('two', 'movies')                  34
# 70                      ('destroy', 'us')                  87
# ...                                   ...                 ...
# 2003867                      ('de', 'le')                  38
# 2047220               ('girls', 'revolt')                  35
# 2092404               ('perez', 'molina')                  36
# 2120951  ('transportation', 'commission')                  44
# 2242636                ('ad', 'blocking')                  42
#
#          non_hyperpartisan_freq                        bigram  freq  \
# 1                           245             (first, official)   380
# 22                          679                (first, thing)  1263
# 40                         1237                  (first, two)  2003
# 41                           26                 (two, movies)    60
# 70                           46                 (destroy, us)   133
# ...                         ...                           ...   ...
# 2003867                     145                      (de, le)   183
# 2047220                      20               (girls, revolt)    55
# 2092404                      27               (perez, molina)    63
# 2120951                     126  (transportation, commission)   170
# 2242636                      30                (ad, blocking)    72
#
#          p_hyperpartisan  p_non_hyperpartisan  o_hyperpartisan  \
# 1               0.001800             0.003267         0.001803
# 22              0.007787             0.009053         0.007848
# 40              0.010213             0.016493         0.010319
# 41              0.000453             0.000347         0.000454
# 70              0.001160             0.000613         0.001161
# ...                  ...                  ...              ...
# 2003867         0.000507             0.001933         0.000507
# 2047220         0.000467             0.000267         0.000467
# 2092404         0.000480             0.000360         0.000480
# 2120951         0.000587             0.001680         0.000587
# 2242636         0.000560             0.000400         0.000560
#
#          o_non_hyperpartisan         r
# 1                   0.003277 -0.597454
# 22                  0.009136 -0.151998
# 40                  0.016770 -0.485627
# 41                  0.000347  0.268371
# 70                  0.000614  0.637814
# ...                      ...       ...
# 2003867             0.001937 -1.340576
# 2047220             0.000267  0.559816
# 2092404             0.000360  0.287802
# 2120951             0.001683 -1.053187
# 2242636             0.000400  0.336632
#
# [69972 rows x 10 columns]

# %%
non_hyper = df.sort_values("r").head(50).reset_index(drop=True)
hyper = df.sort_values("r", ascending=False).head(50).reset_index(drop=True)

# %%
pd.concat([hyper, non_hyper]).to_csv("bigrams_highest.csv", index=False)
